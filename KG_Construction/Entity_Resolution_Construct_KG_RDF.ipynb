# %% [markdown]
# ## Task 1: Entity Resolution (Record Linkage)

# %% [markdown]
# #### Required libraries

# %% [markdown]
# The Record Linkage ToolKit ([RLTK](https://github.com/usc-isi-i2/rltk)) is a general-purpose open-source record linkage platform that allows users to build powerful Python programs that link records referring to the same underlying entity. You can also find additional examples and use-cases in [RLTK's documentation](https://rltk.readthedocs.io/en/master/).

# %%
import rltk
import csv
import pandas as pd
import csv
from rdflib import Graph, URIRef, Literal, XSD, Namespace, RDF
import numpy as np
import rdflib
import io
import os
from datetime import datetime
import pandas as pd
from IPython.display import display
from difflib import SequenceMatcher
import rltk
import re
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Construct RLTK Datasets
#
# #### Read csv file and set a tokenizer

# %%
sizeDict = {'10001+' : '10000+ Employees', 
            '5001-10000' : '5001 to 10000 Employees',
            '1001-5000' : '5001 to 10000 Employees', 
            '501-1000': '501 to 1000 Employees', 
            '251-500' : '201 to 500 Employees',
            '101-250': '51 to 200 Employees', 
            '51-100' : '51 to 200 Employees', 
            '11-50' : '1 to 50 Employees', 
            '1-10' : '1 to 50 Employees'
}

# %%
dir_ = './data/'
crunchbase = dir_ + 'crunchbase_companyInfo2.csv'
glassdoor = dir_ + 'glassdoor_companyInfo2.csv'

# Read csv file to check the shape of data
crunch = pd.read_csv(crunchbase)
glass = pd.read_csv(glassdoor)

# You can use this tokenizer in case you need to manipulate some data
tokenizer = rltk.tokenizer.crf_tokenizer.crf_tokenizer.CrfTokenizer()

# %% [markdown]
# #### Select attributes that are the most useful for the record linkage task. Then construct RLTK datasets with the selected fields.

# %%
class CrunchRecord(rltk.Record):
    def __init__(self, raw_object):
        super().__init__(raw_object)
        self.name = ''

    @rltk.cached_property
    def id(self):
        return self.raw_object['Unnamed: 0']
    
    @rltk.cached_property
    def name_string(self):
        return self.raw_object['name']

    @rltk.cached_property
    def name_tokens(self):
        return set(tokenizer.tokenize(self.name_string))
    
    @rltk.cached_property
    def h_city_string(self):
        return self.raw_object['headquaters_location_city']
    
    @rltk.cached_property
    def h_state_string(self):
        return self.raw_object['headquaters_location_state']
    
    @rltk.cached_property
    def link_string(self):
        return self.raw_object['website_link']

    @rltk.cached_property
    def size_string(self):\
        return self.raw_object['num_employees_enum']
    
    @rltk.cached_property
    def industry_string(self):
        return self.raw_object['industries']

# Read dataset as rltk type
ds1 = rltk.Dataset(rltk.CSVReader(crunchbase), record_class=CrunchRecord)
print(ds1.generate_dataframe().head(2))
# Out:
#   id     name_string        name_tokens h_city_string h_state_string  \
# 0  0  1QVIA Holdings  {1QVIA, Holdings}       Danbury    Connecticut
# 1  1              3M               {3M}    Saint Paul      Minnesota
#
#               link_string            size_string  \
# 0  https://www.iqvia.com/  501 to 1000 Employees
# 1      https://www.3m.com       10000+ Employees
#
#                                      industry_string
# 0       ['Analytics', 'Health Care', 'Life Science']
# 1  ['Automotive', 'Electronics', 'Enterprise Soft...

# %%
class GlassRecord(rltk.Record):
    def __init__(self, raw_object):
        super().__init__(raw_object)
        self.name = ''

    @rltk.cached_property
    def id(self):
        return self.raw_object['Unnamed: 0']
    
    @rltk.cached_property
    def name_string(self):
        return self.raw_object['company']
    
    @rltk.cached_property
    def name_tokens(self):
        return set(tokenizer.tokenize(self.name_string))
    
    @rltk.cached_property
    def headquaters_string(self):
        return self.raw_object['headquarters']
    
    @rltk.cached_property
    def h_city_string(self):
        return self.headquaters_string.split(',')[0]
    
    @rltk.cached_property
    def h_state_string(self):
        if len(self.headquaters_string.split(',')) == 2:
            return self.headquaters_string.split(',')[1]
        else:
            return ''
    
    @rltk.cached_property
    def link_string(self):
        return self.raw_object['website']

    @rltk.cached_property
    def size_string(self):
        return self.raw_object['size']
    
    @rltk.cached_property
    def industry_string(self):
        return self.raw_object['industry'].split(' & ')
    
ds2 = rltk.Dataset(rltk.CSVReader(glassdoor),record_class=GlassRecord)
print(ds2.generate_dataframe().head(2))
print()
# Out:
#   id name_string name_tokens headquaters_string h_city_string h_state_string  \
# 0  0     Walmart   {Walmart}    Bentonville, AR   Bentonville             AR
# 1  1      Amazon    {Amazon}        Seattle, WA       Seattle             WA
#
#            link_string       size_string                     industry_string
# 0  careers.walmart.com  10000+ Employees  [General Merchandise, Superstores]
# 1      www.amazon.jobs  10000+ Employees            [Internet, Web Services]

# %% [markdown]
# ### Entity Linking

# %% [markdown]
# #### Define the functions to calculate similarity between attributes

# %%
def jaccard_list(a, b):
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))

def name_tokens_similarity(r1, r2):
    s1 = r1.name_string
    s2 = r2.name_string
    if rltk.levenshtein_distance(s1, s2) > min(len(s1), len(s2)) / 3:
            return 0
    return 1

def h_city_string_similarity(r1, r2):
    s1 = r1.h_city_string
    s2 = r2.h_city_string
    if s1 == s2:
        return 1
    return 0

def h_state_string_similarity(r1, r2):
    s1 = r1.h_state_string
    s2 = r2.h_state_string
    if s1 == s2:
        return 1
    return 0

def size_string_similarity(r1, r2):
    s1 = r1.size_string
    s2 = r2.size_string
    if s1 == s2:
        return 1
    return 0

def industry_string_similarity(r1, r2):
    s1 = r1.industry_string
    s2 = r2.industry_string
    words1 = set(s1)
    words2 = set(s2)
    return jaccard_list(words1, words2)

# %% [markdown]
# #### Combine multiple similarity functions into a single weightened scoring function:

# %%
# threshold value to determine if we are confident the record match
MY_TRESH = 0.8

# entity linkage scoring function
def rule_based_method(r1, r2):
    score_1 = name_tokens_similarity(r1, r2)
    score_2 = h_city_string_similarity(r1, r2)
    score_3 = size_string_similarity(r1, r2)
    score_4 = industry_string_similarity(r1, r2)
    
    total = 0.78 * score_1  + 0.12 * score_2 + 0.1 * score_3
    
    # return two values: boolean if they match or not, float to determine confidence
    return total >= MY_TRESH, total

# %% [markdown]
# #### Matching the values using rules-based-method

# %%
pairs = []
for r_crunch, r_glass in rltk.get_record_pairs(ds1, ds2):
    result, confidence = rule_based_method(r_crunch, r_glass)
    # print(r_crunch.name_string, r_glass.name_string, result, confidence)
    if result == True:
        pairs.append((r_crunch.id, r_glass.id, r_crunch.name_string, r_glass.name_string, confidence))

# %%
len(pairs)
# Out:
# 452

# %% [markdown]
# ### Save the prediction results
# #### Save the valid pairs (=matching pairs) to 'Entity_resolution.csv'

# %%
header = ['crunchbase.ID', 'glassdoor.ID', 'Crunchbase.CName', 'Glassdoor.CName', 'confidence']
with open(dir_ + 'Entity_resolution.csv', mode='w') as file:
    writer = csv.writer(file, delimiter=',', quotechar='"',quoting=csv.QUOTE_MINIMAL)
    writer.writerow(i for i in header)
    for row in pairs:
        writer.writerow(row)

# %% [markdown]
# <hr>

# %% [markdown]
# # Tasking2 : Using RDFLib for Knowledge Representation

# %% [markdown]
# RDFLib is a Python library for working with RDF, a simple yet powerful language for representing information as graphs. RDFLib aims to be a pythonic RDF API, a Graph is a python collection of RDF Subject, Predicate,  Object Triples.
#
# This notebook introduces simple examples. You can also find additional information in the [official documenation](https://rdflib.readthedocs.io/en/stable/).

# %% [markdown]
# ### Merge two datasets using the matching pairs

# %%
matchDF = pd.read_csv(dir_ + 'Entity_resolution.csv')
matchDF.head()
# Out:
#    crunchbase.ID  glassdoor.ID        Crunchbase.CName  \
# 0              1           101                      3M
# 1              2           445  A-Mark Precious Metals
# 2              3           259                   AECOM
# 3              5           333                    AGCO
# 4              6            66                     AIG
#
#           Glassdoor.CName  confidence
# 0                      3M        1.00
# 1  A-Mark Precious Metals        0.88
# 2                   AECOM        1.00
# 3                    AGCO        1.00
# 4                     AIG        1.00

# %%
crunch = pd.read_csv(crunchbase).drop(columns=['Unnamed: 0.1'])
glass = pd.read_csv(glassdoor).drop(columns=['Unnamed: 0.1'])

# %% [markdown]
# #### Get State abbreviation data from wikidata for preprocessing

# %%
import requests

url = 'https://query.wikidata.org/sparql'
query = '''
SELECT ?itemLabel ?shortname 
WHERE 
{
  # ?item wdt:P31 wd:Q35657 .
  # ?item wdt:P1813 ?shortname .
  FILTER (strlen(?shortname) < 3) .
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
'''
r = requests.get(url, params = {'format': 'json', 'query': query})
data = r.json()

state = []
abb = []
for x in data["results"]["bindings"]:
    state.append(x['itemLabel']['value'])
    abb.append(x['shortname']['value'])

stateDF = pd.DataFrame(state, columns=['state'])
stateDF['abbr'] = abb
stateDF
# Out:
#              state abbr
# 0       California   CA
# 1          Alabama   AL
# 2            Maine   ME
# 3    New Hampshire   NH
# 4    Massachusetts   MA
# 5      Connecticut   CT
# 6           Hawaii   HI
# 7           Alaska   AK
# 8          Florida   FL
# 9          Arizona   AZ
# 10          Oregon   OR
# 11            Utah   UT
# 12        Michigan   MI
# 13        Illinois   IL
# 14    North Dakota   ND
# 15    South Dakota   SD
# 16         Montana   MT
# 17         Wyoming   WY
# 18           Idaho   ID
# 19      Washington   WA
# 20          Nevada   NV
# 21        Colorado   CO
# 22        Virginia   VA
# 23   West Virginia   WV
# 24        New York   NY
# 25    Rhode Island   RI
# 26        Maryland   MD
# 27        Delaware   DE
# 28            Ohio   OH
# 29    Pennsylvania   PA
# 30      New Jersey   NJ
# 31         Indiana   IN
# 32         Georgia   GA
# 33           Texas   TX
# 34  North Carolina   NC
# 35  South Carolina   SC
# 36     Mississippi   MS
# 37       Tennessee   TN
# 38      New Mexico   NM
# 39       Minnesota   MN
# 40       Wisconsin   WI
# 41            Iowa   IA
# 42        Nebraska   NE
# 43          Kansas   KS
# 44        Missouri   MO
# 45       Louisiana   LA
# 46        Kentucky   KY
# 47        Arkansas   AR
# 48        Oklahoma   OK
# 49         Vermont   VT

# %%
glass['headquarters_city'] = ''
glass['headquarters_state'] = ''

for idx, area in enumerate(glass['headquarters']):
    try: 
        city = area.split(', ')[0]
        state = area.split(', ')[1]
        
        abbIndex = stateDF[stateDF.abbr.str.contains(state)].index[0]
        glass.loc[idx, 'headquarters_city'] = city
        glass.loc[idx, 'headquarters_state'] = stateDF.loc[abbIndex, 'state']
    except:
        glass.loc[idx, 'headquarters_city'] = city
        glass.loc[idx, 'headquarters_state'] = state

# %% [markdown]
# ### Construct a knowledge graph, using data matching pairs
# #### Merge

# %%
tot = []
columnTot = list(matchDF.columns[:-1])
columnTot.extend(list(crunch.columns[1:]))
columnTot.extend(list(glass.columns[:]))

for idx in range(len(matchDF)):
    newRow = []
    crunchIdx = list(matchDF.loc[idx,:])[0]
    glassIdx = list(matchDF.loc[idx,:])[1]
    newRow.extend(list(matchDF.iloc[idx,:-1]))
    newRow.extend(list(crunch.iloc[crunchIdx,1:]))
    newRow.extend(list(glass.iloc[glassIdx,:]))
    tot.append(newRow)
    
dfMerge = pd.DataFrame(tot, columns =columnTot)

# %%
mustGlass = ['founded','type','revenue']
rmListGlass = [col for col in list(glass.columns) if col not in mustGlass]
rmList = ['crunchbase.ID', 'glassdoor.ID', 'Crunchbase.CName', 'Glassdoor.CName', 'company']
rmList.extend(rmListGlass)

dfMerge = dfMerge.drop(rmList, axis=1)
dfMerge
# Out:
#                        name headquaters_location_city  \
# 0                        3M                Saint Paul
# 1    A-Mark Precious Metals              Santa Monica
# 2                     AECOM               Los Angeles
# 3                      AGCO                    Duluth
# 4                       AIG                  New York
# ..                      ...                       ...
# 447              Yum Brands                Louisville
# 448      Yum China Holdings                  Shanghai
# 449  Zimmer Biomet Holdings                    Warsaw
# 450                  Zoetis                Parsippany
# 451                    eBay                  San Jose
#
#     headquaters_location_state headquaters_location_country  \
# 0                    Minnesota                United States
# 1                   California                United States
# 2                   California                United States
# 3                      Georgia                United States
# 4                     New York                United States
# ..                         ...                          ...
# 447                   Kentucky                United States
# 448                   Shanghai                        China
# 449                    Indiana                United States
# 450                 New Jersey                United States
# 451                 California                United States
#
#                                    headquaters_regions  \
# 0    ['Greater Minneapolis-Saint Paul Area', 'Great...
# 1    ['Greater Los Angeles Area', 'West Coast', 'We...
# 2    ['Greater Los Angeles Area', 'West Coast', 'We...
# 3    ['Greater Atlanta Area', 'East Coast', 'Southe...
# 4    ['Greater New York Area', 'East Coast', 'North...
# ..                                                 ...
# 447                                    ['Southern US']
# 448                            ['Asia-Pacific (APAC)']
# 449                   ['Great Lakes', 'Midwestern US']
# 450  ['Greater New York Area', 'East Coast', 'North...
# 451  ['San Francisco Bay Area', 'Silicon Valley', '...
#
#                                                founder  \
# 0                                                   []
# 1                                ['Steven C. Markoff']
# 2                                ['Richard G. Newman']
# 3                                ['Robert J. Ratliff']
# 4                           ['Cornelius Vander Starr']
# ..                                                 ...
# 447                             ['Andrall E. Pearson']
# 448                                       ['Joey Wat']
# 449  ['Bryan Huffman', 'J. J. Ettinger', 'Justin O....
# 450                                                 []
# 451                ['Pierre Omidyar', 'Simon Rothman']
#
#                  website_link  \
# 0          https://www.3m.com
# 1        http://www.amark.com
# 2       http://www.aecom.com/
# 3         http://agcocorp.com
# 4         https://www.aig.com
# ..                        ...
# 447        http://www.yum.com
# 448  http://www.yumchina.com/
# 449        https://zimmer.com
# 450    https://www.zoetis.com
# 451           http://ebay.com
#
#                                                    hub  \
# 0                      ['3M Alumni Founded Companies']
# 1                                                   []
# 2                   ['AECOM Alumni Founded Companies']
# 3                                                   []
# 4    ['American International Group Alumni Founded ...
# ..                                                 ...
# 447                                                 []
# 448                                                 []
# 449                                                 []
# 450                                                 []
# 451  ['eBay Alumni Founded Companies', 'eBay Portfo...
#
#           num_employees_enum         last_funding_type  ...  founded_date  \
# 0           10000+ Employees                       NaN  ...          1902
# 1        51 to 200 Employees                       NaN  ...          1965
# 2           10000+ Employees                       NaN  ...           NaN
# 3           10000+ Employees                       NaN  ...          1990
# 4           10000+ Employees                       NaN  ...  Dec 19, 1919
# ..                       ...                       ...  ...           ...
# 447         10000+ Employees                       NaN  ...          1997
# 448         10000+ Employees            Private Equity  ...  May 30, 1997
# 449         10000+ Employees             Post-IPO Debt  ...          1927
# 450  5001 to 10000 Employees                       NaN  ...          2014
# 451         10000+ Employees  Venture - Series Unknown  ...   Sep 1, 1995
#
#     operating_status                            also_known_as company_type  \
# 0             Active                                    3M Co   For Profit
# 1                NaN                                   Active   For Profit
# 2                NaN                                      NaN          NaN
# 3                NaN                                   Active   For Profit
# 4             Active                                      AIG   For Profit
# ..               ...                                      ...          ...
# 447           Active                Tricon Global Restaurants   For Profit
# 448           Active  百胜中国, Baisheng Zhongguo, 环胜电子商务（上海）有限公司   For Profit
# 449              NaN                                   Active   For Profit
# 450           Active                     Pfizer Animal Health   For Profit
# 451              NaN                                   Active   For Profit
#
#     legal_name contact_phone number_of_exits founded                     type  \
# 0       1902.0        Active             2.0  1902.0   Company - Public (MMM)
# 1          NaN           NaN             NaN     NaN  Company - Public (AMRK)
# 2          NaN           NaN             NaN  1990.0   Company - Public (ACM)
# 3          NaN           NaN             NaN  1990.0  Company - Public (AGCO)
# 4          NaN           NaN             1.0  1919.0   Company - Public (AIG)
# ..         ...           ...             ...     ...                      ...
# 447        NaN           NaN             1.0  1997.0   Company - Public (YUM)
# 448        NaN           NaN             1.0     NaN         Company - Public
# 449        NaN           NaN             1.0  1927.0   Company - Public (ZBH)
# 450        NaN           NaN             NaN  2013.0   Company - Public (ZTS)
# 451        NaN           NaN            16.0  1995.0  Company - Public (EBAY)
#
#                       revenue
# 0          $10+ billion (USD)
# 1     $5 to $10 billion (USD)
# 2          $10+ billion (USD)
# 3          $10+ billion (USD)
# 4          $10+ billion (USD)
# ..                        ...
# 447        $10+ billion (USD)
# 448  Unknown / Non-Applicable
# 449   $5 to $10 billion (USD)
# 450   $5 to $10 billion (USD)
# 451        $10+ billion (USD)
#
# [452 rows x 25 columns]

# %%
dfMerge['headquaters_regions'] = dfMerge['headquaters_regions'].apply(eval).apply(', '.join)
dfMerge['founder'] = dfMerge['founder'].apply(eval).apply(', '.join)
dfMerge['hub'] = dfMerge['hub'].apply(eval).apply(', '.join)
dfMerge['industries'] = dfMerge['industries'].apply(eval).apply(', '.join)
dfMerge
# Out:
#                        name headquaters_location_city  \
# 0                        3M                Saint Paul
# 1    A-Mark Precious Metals              Santa Monica
# 2                     AECOM               Los Angeles
# 3                      AGCO                    Duluth
# 4                       AIG                  New York
# ..                      ...                       ...
# 447              Yum Brands                Louisville
# 448      Yum China Holdings                  Shanghai
# 449  Zimmer Biomet Holdings                    Warsaw
# 450                  Zoetis                Parsippany
# 451                    eBay                  San Jose
#
#     headquaters_location_state headquaters_location_country  \
# 0                    Minnesota                United States
# 1                   California                United States
# 2                   California                United States
# 3                      Georgia                United States
# 4                     New York                United States
# ..                         ...                          ...
# 447                   Kentucky                United States
# 448                   Shanghai                        China
# 449                    Indiana                United States
# 450                 New Jersey                United States
# 451                 California                United States
#
#                                    headquaters_regions  \
# 0    Greater Minneapolis-Saint Paul Area, Great Lak...
# 1     Greater Los Angeles Area, West Coast, Western US
# 2     Greater Los Angeles Area, West Coast, Western US
# 3        Greater Atlanta Area, East Coast, Southern US
# 4    Greater New York Area, East Coast, Northeaster...
# ..                                                 ...
# 447                                        Southern US
# 448                                Asia-Pacific (APAC)
# 449                         Great Lakes, Midwestern US
# 450  Greater New York Area, East Coast, Northeaster...
# 451  San Francisco Bay Area, Silicon Valley, West C...
#
#                                              founder  \
# 0
# 1                                  Steven C. Markoff
# 2                                  Richard G. Newman
# 3                                  Robert J. Ratliff
# 4                             Cornelius Vander Starr
# ..                                               ...
# 447                               Andrall E. Pearson
# 448                                         Joey Wat
# 449  Bryan Huffman, J. J. Ettinger, Justin O. Zimmer
# 450
# 451                    Pierre Omidyar, Simon Rothman
#
#                  website_link  \
# 0          https://www.3m.com
# 1        http://www.amark.com
# 2       http://www.aecom.com/
# 3         http://agcocorp.com
# 4         https://www.aig.com
# ..                        ...
# 447        http://www.yum.com
# 448  http://www.yumchina.com/
# 449        https://zimmer.com
# 450    https://www.zoetis.com
# 451           http://ebay.com
#
#                                                    hub  \
# 0                          3M Alumni Founded Companies
# 1
# 2                       AECOM Alumni Founded Companies
# 3
# 4    American International Group Alumni Founded Co...
# ..                                                 ...
# 447
# 448
# 449
# 450
# 451  eBay Alumni Founded Companies, eBay Portfolio ...
#
#           num_employees_enum         last_funding_type  ...  founded_date  \
# 0           10000+ Employees                       NaN  ...          1902
# 1        51 to 200 Employees                       NaN  ...          1965
# 2           10000+ Employees                       NaN  ...           NaN
# 3           10000+ Employees                       NaN  ...          1990
# 4           10000+ Employees                       NaN  ...  Dec 19, 1919
# ..                       ...                       ...  ...           ...
# 447         10000+ Employees                       NaN  ...          1997
# 448         10000+ Employees            Private Equity  ...  May 30, 1997
# 449         10000+ Employees             Post-IPO Debt  ...          1927
# 450  5001 to 10000 Employees                       NaN  ...          2014
# 451         10000+ Employees  Venture - Series Unknown  ...   Sep 1, 1995
#
#     operating_status                            also_known_as company_type  \
# 0             Active                                    3M Co   For Profit
# 1                NaN                                   Active   For Profit
# 2                NaN                                      NaN          NaN
# 3                NaN                                   Active   For Profit
# 4             Active                                      AIG   For Profit
# ..               ...                                      ...          ...
# 447           Active                Tricon Global Restaurants   For Profit
# 448           Active  百胜中国, Baisheng Zhongguo, 环胜电子商务（上海）有限公司   For Profit
# 449              NaN                                   Active   For Profit
# 450           Active                     Pfizer Animal Health   For Profit
# 451              NaN                                   Active   For Profit
#
#     legal_name contact_phone number_of_exits founded                     type  \
# 0       1902.0        Active             2.0  1902.0   Company - Public (MMM)
# 1          NaN           NaN             NaN     NaN  Company - Public (AMRK)
# 2          NaN           NaN             NaN  1990.0   Company - Public (ACM)
# 3          NaN           NaN             NaN  1990.0  Company - Public (AGCO)
# 4          NaN           NaN             1.0  1919.0   Company - Public (AIG)
# ..         ...           ...             ...     ...                      ...
# 447        NaN           NaN             1.0  1997.0   Company - Public (YUM)
# 448        NaN           NaN             1.0     NaN         Company - Public
# 449        NaN           NaN             1.0  1927.0   Company - Public (ZBH)
# 450        NaN           NaN             NaN  2013.0   Company - Public (ZTS)
# 451        NaN           NaN            16.0  1995.0  Company - Public (EBAY)
#
#                       revenue
# 0          $10+ billion (USD)
# 1     $5 to $10 billion (USD)
# 2          $10+ billion (USD)
# 3          $10+ billion (USD)
# 4          $10+ billion (USD)
# ..                        ...
# 447        $10+ billion (USD)
# 448  Unknown / Non-Applicable
# 449   $5 to $10 billion (USD)
# 450   $5 to $10 billion (USD)
# 451        $10+ billion (USD)
#
# [452 rows x 25 columns]

# %% [markdown]
# ### Create a graph

# %%
import rdflib
MYNS = Namespace('http://dsci558.org/myprojectnamespace#')
RDFS = Namespace("http://www.w3.org/2000/01/rdf-schema#")
SCHEMA = Namespace("https://schema.org/")
WIKIDATA = Namespace("https://wikidata.org/")

# %%
my_kg = Graph()
my_kg.bind('shema', SCHEMA) # Schema
my_kg.bind('myns', MYNS)
my_kg.bind('rdfs', RDFS)
my_kg.bind('wiki', WIKIDATA)

# %% [markdown]
# ### Triple for Company information
#
# #### Define a URI, then add a simple triple to the graph

# %%
## Company Entities
companyList = []
companyList.extend(glass['company'])
companyList.extend(crunch['name'])
companyList = list(set(companyList))
                            
for company in companyList:
    company_rename = re.sub("[^1-9a-zA-Z&]", "_", company)
    company_uri = URIRef(MYNS[company_rename])
    my_kg.add((company_uri, RDF.type, MYNS['company']))
    my_kg.add((company_uri, RDF.type, SCHEMA.Corporation))
    my_kg.add((company_uri, RDFS.label, Literal(company)))

    
## State Entities
for state in stateDF['state']:
    state = re.sub("[^1-9a-zA-Z&]", "_", state)
    state_uri = URIRef(MYNS[state])
    my_kg.add((state_uri, RDF.type, MYNS['Headquarter_state']))
    my_kg.add((state_uri, RDF.type, SCHEMA.State))
    my_kg.add((state_uri, RDFS.label, Literal(state)))
    
              
## City Entities
cityList = []
cityList.extend(glass['headquarters_city'].fillna("nan"))
cityList.extend(crunch['headquaters_location_city'].fillna("nan"))
cityList = list(set(cityList))
for city in cityList[1:]:
    city = re.sub("[^1-9a-zA-Z&]", "_", city)
    city_uri = URIRef(MYNS[city])
    my_kg.add((city_uri, RDF.type, MYNS['Headquarter_city']))
    my_kg.add((city_uri, RDF.type, SCHEMA.City))
    my_kg.add((city_uri, RDFS.label, Literal(city)))
    

## Country Entities
countryList = []
countryList.extend(crunch['headquaters_location_country'].fillna("nan"))
countryList = list(set(countryList))
for country in countryList:
    country = re.sub("[^1-9a-zA-Z&]", "_", country)
    country_uri = URIRef(MYNS[country])
    my_kg.add((country_uri, RDF.type, MYNS['Headquarter_city']))
    my_kg.add((country_uri, RDF.type, SCHEMA.Country))
    my_kg.add((country_uri, RDFS.label, Literal(country)))


## Add other predicates
predicateList = list(dfMerge.columns)
removeList = ['headquaters_location_city', 'headquaters_location_state', 'headquaters_location_country', 'headquaters_regions']
for rm in removeList:
    predicateList.remove(rm)
for predicate in predicateList:
    predicate_rename = re.sub("[^1-9a-zA-Z&]", "_", predicate)
    predicate_uri = MYNS[predicate_rename]
    my_kg.add((predicate_uri, RDF.type, RDF.Property))
    my_kg.add((predicate_uri, RDFS.label, Literal(predicate, lang = 'en')))

# %%
for idx, row in dfMerge.iterrows():
    company_uri = re.sub("[^1-9a-zA-Z&]", "_", row['name'])
    
    colList = list(dfMerge.columns)[1:]
    for col in colList:
        obj = row[col]
        if str(obj) != 'nan' and str(obj) != '[]':
            try:
                obj = str(int(obj))            
                my_kg.add((MYNS[company_uri], MYNS[col], Literal(obj)))  
            except:
                obj = str(obj)          
                my_kg.add((MYNS[company_uri], MYNS[col], Literal(obj)))

# %% [markdown]
# #### Dump our graph triples into some `ttl` file:

# %%
my_kg.serialize('company.ttl', format="turtle")
# Out:
# <Graph identifier=N1086ff8801f945a69b76e989b03a837b (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ### Triple for Job postings
#
# #### Define a URI, then add a simple triple to the graph

# %%
def get_token(string):
    data = string.split()
    return data[0]

def get_state(string):
    data = string.strip().split(',')
    if len(data) > 1:
        state = data[-1].strip()
        try:
            index = list(stateDF['abbr']).index(state)
            state = stateDF.loc[index,'state']
            return state
        except: 
            return state
        return 
    else:
        return 'Remote'
    
def get_city(string):
    data = string.strip().split(',')
    if len(data) > 1:
        city = data[0].strip()
        return city
    else:
        return None

# %%
job = pd.read_csv('./data/job_info.csv').drop(columns=['Unnamed: 0'])
job['State'] = job['Location'].apply(lambda x: get_state(x))
job['City'] = job['Location'].apply(lambda x: get_city(x))
job['Company_token'] = job['Company'].apply(lambda x: get_token(x))
job['Company_final'] = job['Company'].copy()

job.tail()
# Out:
#                                  Title  Company  \
# 29358  Sr. Analyst, Learning Analytics  Comcast
# 29359  Sr. Analyst, Learning Analytics  Comcast
# 29360  Sr. Analyst, Learning Analytics  Effectv
# 29361  Sr. Analyst, Learning Analytics  Comcast
# 29362  Sr. Analyst, Learning Analytics  Comcast
#
#                          Company_Link       Location  Company_Score  \
# 29358  http://www.comcastcareers.com/  Englewood, CO            3.9
# 29359  http://www.comcastcareers.com/  Englewood, CO            3.9
# 29360         http://www.effectv.com/  Englewood, CO            3.7
# 29361  http://www.comcastcareers.com/  Englewood, CO            3.9
# 29362  http://www.comcastcareers.com/  Englewood, CO            3.9
#
#        Salary_LowerBound  Salary_HigherBound Salary_Type  Post_Duration  \
# 29358               78.0               107.0        Year             31
# 29359               78.0               107.0        Year              8
# 29360               78.0               107.0        Year             14
# 29361               78.0               107.0        Year             31
# 29362               78.0               107.0        Year             18
#
#                            Job_Type  \
# 29358  Information Security Analyst
# 29359  Information Security Analyst
# 29360  Information Security Analyst
# 29361  Information Security Analyst
# 29362  Information Security Analyst
#
#                                         Application_Link  \
# 29358  www.glassdoor.com/partner/jobListing.htm?pos=1...
# 29359  www.glassdoor.com/partner/jobListing.htm?pos=1...
# 29360  www.glassdoor.com/partner/jobListing.htm?pos=1...
# 29361  www.glassdoor.com/partner/jobListing.htm?pos=1...
# 29362  www.glassdoor.com/partner/jobListing.htm?pos=1...
#
#                                          Job_Description  \
# 29358  Comcast’s Technology, Product & Experience org...
# 29359  Comcast Business offers technology solutions r...
# 29360  Effectv, the advertising sales division of Com...
# 29361  Comcast brings together the best in media and ...
# 29362  Comcast brings together the best in media and ...
#
#       Programming_Languages                Soft_Requirements  \
# 29358            ['Python']                     ['database']
# 29359               ['SQL']                     ['database']
# 29360     ['Python', 'SQL']  ['work experience', 'bachelor']
# 29361     ['Python', 'SQL']                     ['database']
# 29362     ['Python', 'SQL']  ['work experience', 'bachelor']
#
#       Framework_Requirements     State       City Company_token Company_final
# 29358              ['Spark']  Colorado  Englewood       Comcast       Comcast
# 29359             ['Hadoop']  Colorado  Englewood       Comcast       Comcast
# 29360              ['Linux']  Colorado  Englewood       Effectv       Effectv
# 29361              ['Spark']  Colorado  Englewood       Comcast       Comcast
# 29362              ['Spark']  Colorado  Englewood       Comcast       Comcast

# %%
len(list(np.setdiff1d(np.array(job['Company']), np.array(dfMerge['name']))))
# Out:
# 2709

# %% [markdown]
# #### Preprocessing to matching the compaines

# %%
dfMerge['website_link_prepro'] = dfMerge['website_link'].str.replace('https:','')
dfMerge['website_link_prepro'] = dfMerge['website_link_prepro'].str.replace('http:','')
dfMerge['website_link_prepro'] = dfMerge['website_link_prepro'].str.replace('/','')
dfMerge['website_link_prepro'] = dfMerge['website_link_prepro'].str.replace('www.','')

job['Company_Link_prepro'] = job['Company_Link'].str.replace('https:','')
job['Company_Link_prepro'] = job['Company_Link_prepro'].str.replace('http:','')
job['Company_Link_prepro'] = job['Company_Link_prepro'].str.replace('/','')
job['Company_Link_prepro'] = job['Company_Link_prepro'].str.replace('www.','')

# %%
company_matching = {}
for idx, row in dfMerge.iterrows():
    company_matching[row['website_link_prepro']] = row['name']
    
from difflib import SequenceMatcher
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
NoNeedCompany = []
CompanyDB = list(dfMerge['name'])

for idx, row in job.iterrows():
    if row['Company'] not in CompanyDB:
        if row['Company_Link_prepro'] in list(company_matching.keys()):
            job.at[idx, 'Company_final'] = company_matching[row['Company_Link_prepro']]
            continue
            
        for website, cname in company_matching.items():
            try:
                score = similar(row['Company_Link_prepro'], website)
                if score >= 0.7:
                    job.at[idx, 'Company_final'] = cname
                    break
            except:
                NoNeedCompany.append(idx)

# %% [markdown]
# #### Drop the companies which do not have any info

# %%
job = job.drop(NoNeedCompany).reset_index(drop=True)
job.head()
# Out:
#                                                Title        Company  \
# 0                               Software Engineer II      Honeywell
# 1                               Software Engineer II      Honeywell
# 2                               Software Engineer II  The RMR Group
# 3  Building Automation Application Engineer (Loca...  The RMR Group
# 4  Building Automation Application Engineer (Loca...      Honeywell
#
#                 Company_Link       Location  Company_Score  Salary_LowerBound  \
# 0  http://www.honeywell.com/  Aguadilla, PR            4.0               61.0
# 1  http://www.honeywell.com/  Aguadilla, PR            4.0               61.0
# 2   http://www.rmrgroup.com/  Aguadilla, PR            3.7               61.0
# 3   http://www.rmrgroup.com/     Newton, MA            3.7               54.0
# 4  http://www.honeywell.com/     Newton, MA            4.0               54.0
#
#    Salary_HigherBound Salary_Type  Post_Duration                  Job_Type  \
# 0                81.0        Year              3        software developer
# 1                81.0        Year             28        software developer
# 2                81.0        Year             10        software developer
# 3                73.0        Year             10  Cloud Computing Engineer
# 4                73.0        Year             21  Cloud Computing Engineer
#
#                                     Application_Link  \
# 0  www.glassdoor.com/partner/jobListing.htm?pos=1...
# 1  www.glassdoor.com/partner/jobListing.htm?pos=1...
# 2  www.glassdoor.com/partner/jobListing.htm?pos=1...
# 3  www.glassdoor.com/partner/jobListing.htm?pos=1...
# 4  www.glassdoor.com/partner/jobListing.htm?pos=1...
#
#                                      Job_Description  \
# 0  Join a team recognized for leadership, innovat...
# 1  Advanced Cloud Developer\nAdvanced Cloud Devel...
# 2  Overview:\nSeeking a highly motivated building...
# 3  Overview:\nSeeking a highly motivated building...
# 4  Join a team recognized for leadership, innovat...
#
#                   Programming_Languages  \
# 0  ['Java', 'JavaScript', 'SQL', 'CSS']
# 1                              ['Java']
# 2                            ['Python']
# 3                            ['Python']
# 4                      ['Java', 'HTML']
#
#                              Soft_Requirements Framework_Requirements  \
# 0  ['work experience', 'bachelor', 'database']              ['Redis']
# 1              ['work experience', 'bachelor']              ['JUnit']
# 2                     ['bachelor', 'database']              ['Spark']
# 3                     ['bachelor', 'database']              ['Spark']
# 4                                ['front end']              ['Spark']
#
#            State       City Company_token            Company_final  \
# 0             PR  Aguadilla     Honeywell  Honeywell International
# 1             PR  Aguadilla     Honeywell  Honeywell International
# 2             PR  Aguadilla           The                Citigroup
# 3  Massachusetts     Newton           The                Citigroup
# 4  Massachusetts     Newton     Honeywell  Honeywell International
#
#   Company_Link_prepro
# 0       honeywell.com
# 1       honeywell.com
# 2        rmrgroup.com
# 3        rmrgroup.com
# 4       honeywell.com

# %%
list1 = map(lambda x: x.capitalize(), job['Job_Type'])
job['Job_Type'] = list(list1)

# %%
job['Programming_Languages'] = job['Programming_Languages'].apply(eval).apply(', '.join)
job['Soft_Requirements'] = job['Soft_Requirements'].apply(eval).apply(', '.join)
job['Framework_Requirements'] = job['Framework_Requirements'].apply(eval).apply(', '.join)
job
# Out:
#                                                    Title        Company  \
# 0                                   Software Engineer II      Honeywell
# 1                                   Software Engineer II      Honeywell
# 2                                   Software Engineer II  The RMR Group
# 3      Building Automation Application Engineer (Loca...  The RMR Group
# 4      Building Automation Application Engineer (Loca...      Honeywell
# ...                                                  ...            ...
# 20688                    Sr. Analyst, Learning Analytics        Comcast
# 20689                    Sr. Analyst, Learning Analytics        Comcast
# 20690                    Sr. Analyst, Learning Analytics        Comcast
# 20691                    Sr. Analyst, Learning Analytics        Comcast
# 20692                    Sr. Analyst, Learning Analytics        Comcast
#
#                          Company_Link       Location  Company_Score  \
# 0           http://www.honeywell.com/  Aguadilla, PR            4.0
# 1           http://www.honeywell.com/  Aguadilla, PR            4.0
# 2            http://www.rmrgroup.com/  Aguadilla, PR            3.7
# 3            http://www.rmrgroup.com/     Newton, MA            3.7
# 4           http://www.honeywell.com/     Newton, MA            4.0
# ...                               ...            ...            ...
# 20688  http://www.comcastcareers.com/  Englewood, CO            3.9
# 20689  http://www.comcastcareers.com/  Englewood, CO            3.9
# 20690  http://www.comcastcareers.com/  Englewood, CO            3.9
# 20691  http://www.comcastcareers.com/  Englewood, CO            3.9
# 20692  http://www.comcastcareers.com/  Englewood, CO            3.9
#
#        Salary_LowerBound  Salary_HigherBound Salary_Type  Post_Duration  \
# 0                   61.0                81.0        Year              3
# 1                   61.0                81.0        Year             28
# 2                   61.0                81.0        Year             10
# 3                   54.0                73.0        Year             10
# 4                   54.0                73.0        Year             21
# ...                  ...                 ...         ...            ...
# 20688               78.0               107.0        Year              1
# 20689               78.0               107.0        Year             31
# 20690               78.0               107.0        Year              8
# 20691               78.0               107.0        Year             31
# 20692               78.0               107.0        Year             18
#
#                            Job_Type  \
# 0                Software developer
# 1                Software developer
# 2                Software developer
# 3          Cloud computing engineer
# 4          Cloud computing engineer
# ...                             ...
# 20688  Information security analyst
# 20689  Information security analyst
# 20690  Information security analyst
# 20691  Information security analyst
# 20692  Information security analyst
#
#                                         Application_Link  \
# 0      www.glassdoor.com/partner/jobListing.htm?pos=1...
# 1      www.glassdoor.com/partner/jobListing.htm?pos=1...
# 2      www.glassdoor.com/partner/jobListing.htm?pos=1...
# 3      www.glassdoor.com/partner/jobListing.htm?pos=1...
# 4      www.glassdoor.com/partner/jobListing.htm?pos=1...
# ...                                                  ...
# 20688  www.glassdoor.com/partner/jobListing.htm?pos=1...
# 20689  www.glassdoor.com/partner/jobListing.htm?pos=1...
# 20690  www.glassdoor.com/partner/jobListing.htm?pos=1...
# 20691  www.glassdoor.com/partner/jobListing.htm?pos=1...
# 20692  www.glassdoor.com/partner/jobListing.htm?pos=1...
#
#                                          Job_Description  \
# 0      Join a team recognized for leadership, innovat...
# 1      Advanced Cloud Developer\nAdvanced Cloud Devel...
# 2      Overview:\nSeeking a highly motivated building...
# 3      Overview:\nSeeking a highly motivated building...
# 4      Join a team recognized for leadership, innovat...
# ...                                                  ...
# 20688  Comcast brings together the best in media and ...
# 20689  Comcast’s Technology, Product & Experience org...
# 20690  Comcast Business offers technology solutions r...
# 20691  Comcast brings together the best in media and ...
# 20692  Comcast brings together the best in media and ...
#
#             Programming_Languages                    Soft_Requirements  \
# 0      Java, JavaScript, SQL, CSS  work experience, bachelor, database
# 1                            Java            work experience, bachelor
# 2                          Python                   bachelor, database
# 3                          Python                   bachelor, database
# 4                      Java, HTML                            front end
# ...                           ...                                  ...
# 20688                         SQL                             database
# 20689                      Python                             database
# 20690                         SQL                             database
# 20691                 Python, SQL                             database
# 20692                 Python, SQL            work experience, bachelor
#
#       Framework_Requirements          State       City Company_token  \
# 0                      Redis             PR  Aguadilla     Honeywell
# 1                      JUnit             PR  Aguadilla     Honeywell
# 2                      Spark             PR  Aguadilla           The
# 3                      Spark  Massachusetts     Newton           The
# 4                      Spark  Massachusetts     Newton     Honeywell
# ...                      ...            ...        ...           ...
# 20688                  Spark       Colorado  Englewood       Comcast
# 20689                  Spark       Colorado  Englewood       Comcast
# 20690                 Hadoop       Colorado  Englewood       Comcast
# 20691                  Spark       Colorado  Englewood       Comcast
# 20692                  Spark       Colorado  Englewood       Comcast
#
#                  Company_final Company_Link_prepro
# 0      Honeywell International       honeywell.com
# 1      Honeywell International       honeywell.com
# 2                    Citigroup        rmrgroup.com
# 3                    Citigroup        rmrgroup.com
# 4      Honeywell International       honeywell.com
# ...                        ...                 ...
# 20688                  Comcast  comcastcareers.com
# 20689                  Comcast  comcastcareers.com
# 20690                  Comcast  comcastcareers.com
# 20691                  Comcast  comcastcareers.com
# 20692                  Comcast  comcastcareers.com
#
# [20693 rows x 20 columns]

# %%
# ## Job posting Entities
# for idx, jobposting in enumerate(job['Title']):
#     jobname = 'job_' + str(idx)
#     job_uri = URIRef(MYNS[jobname])
#     my_kg.add((job_uri, RDF.type, MYNS['jobs']))
#     my_kg.add((job_uri, RDFS.label, Literal(jobname)))
    
## Add other predicates
predicateList = list(job.columns)
removeList = ['Company','Location', 'State', 'City', 'Company_token', 'Company_final', 'Company_Link', 'Company_Link_prepro']
for rm in removeList:
    predicateList.remove(rm)
for predicate in predicateList:
    predicate_rename = re.sub("[^1-9a-zA-Z&.]", "_", predicate)
    predicate_uri = MYNS[predicate_rename]
    my_kg.add((predicate_uri, RDF.type, RDF.Property))
    my_kg.add((predicate_uri, RDFS.label, Literal(predicate, lang = 'en')))

    if predicate == 'State':
        my_kg.add((predicate_uri, RDF.type, SCHEMA.State))
    if predicate == 'City':
        my_kg.add((predicate_uri, RDF.type, SCHEMA.City))

# %%
for idx, row in job.iterrows():
    jobname = 'job_' + str(idx)
    job_uri = URIRef(MYNS[jobname])
    my_kg.add((job_uri, RDF.type, MYNS['jobs']))
    my_kg.add((job_uri, RDFS.label, Literal(jobname)))
    
    colList = list(job.columns)
    for col in colList:
        if col in ['Company','Location', 'Company_token', 'Company_Link', 'Company_Link_prepro']:
            continue
        
        obj = row[col]
        if col == 'Company_final':
            col_rename = 'Company'
            obj_rename = re.sub("[^1-9a-zA-Z&]", "_", obj)
            my_kg.add((MYNS[job_uri], MYNS['Company'], MYNS[obj_rename]))
            my_kg.add((MYNS[job_uri], MYNS['Company'], Literal(obj)))
            
        else:
            if str(obj) != 'nan' and str(obj) != '[]':
                try:
                    obj = str(int(obj))            
                    my_kg.add((MYNS[job_uri], MYNS[col], Literal(obj)))  
                except:
                    obj = str(obj)
                    my_kg.add((MYNS[job_uri], MYNS[col], Literal(obj)))

# %%
my_kg.serialize('KG2.ttl', format="turtle")
# Out:
# <Graph identifier=N1086ff8801f945a69b76e989b03a837b (<class 'rdflib.graph.Graph'>)>
